# %%
#Bai lab 2 
from PIL import Image
import math
import scipy
import numpy as np
import imageio.v2 as iio
import matplotlib.pylab as plt

# Mở ảnh mức xám
img = Image.open('cup.jpg').convert('L')

# Chuyển ảnh sang mảng NumPy
im_1 = np.asarray(img)

# Đảo ảnh: pixel mới = 255 - pixel cũ
im_2 = 255 - im_1

# Chuyển mảng NumPy trở lại ảnh
new_img = Image.fromarray(im_2)

# Hiển thị ảnh gốc
img.show()

# Hiển thị ảnh đảo bằng matplotlib
plt.imshow(new_img, cmap='gray')
plt.show()

# %%
# !pip install pillow
# !pip install scipy
# !pip install imageio
# !pip install matplotlib
# Out:
# Requirement already satisfied: pillow in c:\users\administrator\documents\github\thuc_hanh_nhap_mon_xu_ly_anh_so\.venv\lib\site-packages (11.3.0)
# Requirement already satisfied: scipy in c:\users\administrator\documents\github\thuc_hanh_nhap_mon_xu_ly_anh_so\.venv\lib\site-packages (1.16.0)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\administrator\documents\github\thuc_hanh_nhap_mon_xu_ly_anh_so\.venv\lib\site-packages (from scipy) (2.3.1)
# Requirement already satisfied: imageio in c:\users\administrator\documents\github\thuc_hanh_nhap_mon_xu_ly_anh_so\.venv\lib\site-packages (2.37.0)
# Requirement already satisfied: numpy in c:\users\administrator\documents\github\thuc_hanh_nhap_mon_xu_ly_anh_so\.venv\lib\site-packages (from imageio) (2.3.1)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\administrator\documents\github\thuc_hanh_nhap_mon_xu_ly_anh_so\.venv\lib\site-packages (from imageio) (11.3.0)
# Collecting matplotlib
#   Downloading matplotlib-3.10.3-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.2-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.59.0-cp313-cp313-win_amd64.whl.metadata (110 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\administrator\documents\github\thuc_hanh_nhap_mon_xu_ly_anh_so\.venv\lib\site-packages (from matplotlib) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\administrator\documents\github\thuc_hanh_nhap_mon_xu_ly_anh_so\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\administrator\documents\github\thuc_hanh_nhap_mon_xu_ly_anh_so\.venv\lib\site-packages (from matplotlib) (11.3.0)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\administrator\documents\github\thuc_hanh_nhap_mon_xu_ly_anh_so\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\administrator\documents\github\thuc_hanh_nhap_mon_xu_ly_anh_so\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.3-cp313-cp313-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----------------------------------- ---- 7.1/8.1 MB 43.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 34.9 MB/s eta 0:00:00
# Downloading contourpy-1.3.2-cp313-cp313-win_amd64.whl (223 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.59.0-cp313-cp313-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 16.9 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp313-cp313-win_amd64.whl (71 kB)
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    -------------------- ------------------- 3/6 [cycler]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    ---------------------------------------- 6/6 [matplotlib]
#
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.59.0 kiwisolver-1.4.8 matplotlib-3.10.3 pyparsing-3.2.3

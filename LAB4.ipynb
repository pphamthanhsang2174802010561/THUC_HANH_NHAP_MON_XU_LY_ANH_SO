# %% [markdown]
# THUC HANH LAB 4

# %%
#1. cài đặt thư viện
# !pip install opencv-python
# !pip install scikit-image
# Out:
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------- ----------------- 7.3/12.9 MB 48.4 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 59.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 95.8 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/4 [tifffile]
#    ---------- ----------------------------- 1/4 [networkx]
#    ---------- ----------------------------- 1/4 [networkx]
#    ---------- ----------------------------- 1/4 [networkx]
#    ---------- ----------------------------- 1/4 [networkx]
#    ---------- ----------------------------- 1/4 [networkx]
#    ---------- ----------------------------- 1/4 [networkx]
#    ---------- ----------------------------- 1/4 [networkx]
#    ---------- ----------------------------- 1/4 [networkx]
#    ------------------------------ --------- 3/4 [scikit-image]
# ...

# %%
#2. Viết chương trình pâh vùng ảnh
#2.1 Phân vùng theo histogram
#2.1.1 Phương pháp otsu
from PIL import Image
import numpy as np
import imageio.v2 as iio
import scipy.ndimage as nd
import matplotlib.pylab as plt
from skimage.filters.thresholding import threshold_otsu

# Đọc ảnh và chuyển sang grayscale
data = Image.open('fruit.jpg').convert('L')

# Chuyển đổi ảnh thành mảng numpy
a = np.asarray(data)

# Thực hiện phân ngưỡng Otsu
thres = threshold_otsu(a)

# Lọc các pixel có giá trị lớn hơn ngưỡng
b = a > thres

# Chuyển đổi kết quả về dạng ảnh
b = Image.fromarray(b)

# Hiển thị ảnh kết quả
plt.imshow(b)
plt.show()

# %%
#2.1.2 Phương pháp adaptive thresholding
from PIL import Image
import numpy as np
import imageio.v2 as iio
import scipy.ndimage as nd
import matplotlib.pylab as plt
from skimage.filters import threshold_local

# Đọc ảnh và chuyển sang grayscale
data = Image.open('fruit.jpg').convert('L')

# Chuyển đổi ảnh thành mảng numpy
a = np.asarray(data)

# Thực hiện phân ngưỡng địa phương (local thresholding)
b = threshold_local(a, 39, offset=10)

# Chuyển đổi kết quả về dạng ảnh
b = Image.fromarray(b)

# Hiển thị ảnh kết quả
plt.imshow(b)
plt.show()

# %%
#$2.3 Biến đổi đối tượng trong ảnh
#2.3.1 Sử dụng binary_dilation
import cv2
from PIL import Image
import numpy as np
import imageio.v2 as iio
import scipy.ndimage as nd
from scipy.ndimage import label
import matplotlib.pylab as plt
from skimage.filters import threshold_local

# Mở ảnh và chuyển sang grayscale
data = Image.open('anh.gif').convert('L')

# Thực hiện phép binary dilation
b = nd.binary_dilation(data, iterations=50)

# Chuyển đổi kết quả từ mảng Boolean thành ảnh
c = Image.fromarray(b)

# Hiển thị ảnh kết quả
c.show()
plt.imshow(c)
plt.show()
